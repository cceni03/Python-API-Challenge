# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
print("Beginning Data Retrieval")
print("------------------------")

# Counter that states number of cities
counter = 1

# set up lists to hold reponse info
country =[]
lat = []
lon =[]
temp = []
humid = []
cloud = []
wind = []
cities_found = []
date = []
units = "imperial"

# Loop through the list of cities and perform a request for data on each
for city in cities:
    print(f'Processing Record {counter} of set {counter} | {city}')
    
    counter += 1
    
    # Build partial query URL
    query_url = url + "appid=" + weather_api_key + "&units=" + units + "&q=" + city
    
    try:
        weather_response = requests.get(query_url).json()
        # Print weather response
        country.append(weather_response['sys']['country'])
        lat.append(weather_response['coord']['lat'])
        lon.append(weather_response['coord']['lon'])
        temp.append(weather_response['main']['temp'])
        humid.append(weather_response['main']['humidity'])
        cloud.append(weather_response['clouds']['all'])
        wind.append(weather_response['wind']['speed'])
        cities_found.append(weather_response['name'])
        date.append(weather_response['dt'])
    except:
        print(f'City, {city} not found. Skipping...')
        
print("--------------------------------------------")
print("Data Retrieval Complete")
print("--------------------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of set 1 | tuktoyaktuk
# Processing Record 2 of set 2 | puerto ayora
# Processing Record 3 of set 3 | aban
# Processing Record 4 of set 4 | abu samrah
# Processing Record 5 of set 5 | shu
# Processing Record 6 of set 6 | fairbanks
# Processing Record 7 of set 7 | arifwala
# Processing Record 8 of set 8 | bethel
# Processing Record 9 of set 9 | kununurra
# Processing Record 10 of set 10 | east london
# Processing Record 11 of set 11 | ribeira grande
# Processing Record 12 of set 12 | venado tuerto
# Processing Record 13 of set 13 | new norfolk
# Processing Record 14 of set 14 | hermanus
# Processing Record 15 of set 15 | butaritari
# Processing Record 16 of set 16 | bluff
# Processing Record 17 of set 17 | albany
# Processing Record 18 of set 18 | luena
# Processing Record 19 of set 19 | mataura
# Processing Record 20 of set 20 | upernavik
# Processing Record 21 of set 21 | fare
# Processing Record 22 of set 22 | ushuaia
# Processing Record 23 of set 23 | saskylakh
# Processing Record 24 of set 24 | punta arenas
# Processing Record 25 of set 25 | muyezerskiy
# Processing Record 26 of set 26 | zhezkazgan
# Processing Record 27 of set 27 | rocha
# Processing Record 28 of set 28 | irmo
# Processing Record 29 of set 29 | toliary
# City, toliary not found. Skipping...
# Processing Record 30 of set 30 | leningradskiy
# Processing Record 31 of set 31 | bolungarvik
# City, bolungarvik not found. Skipping...
# Processing Record 32 of set 32 | busselton
# Processing Record 33 of set 33 | sharjah
# Processing Record 34 of set 34 | san cristobal
# Processing Record 35 of set 35 | ardakan
# City, ardakan not found. Skipping...
# Processing Record 36 of set 36 | camocim
# Processing Record 37 of set 37 | chokurdakh
# Processing Record 38 of set 38 | saint george
# Processing Record 39 of set 39 | sitka
# Processing Record 40 of set 40 | barentsburg
# City, barentsburg not found. Skipping...
# Processing Record 41 of set 41 | lata
# Processing Record 42 of set 42 | port alfred
# Processing Record 43 of set 43 | umtata
# Processing Record 44 of set 44 | lithgow
# Processing Record 45 of set 45 | hilo
# Processing Record 46 of set 46 | melo
# Processing Record 47 of set 47 | taolanaro
# City, taolanaro not found. Skipping...
# Processing Record 48 of set 48 | makakilo city
# Processing Record 49 of set 49 | masallatah
# Processing Record 50 of set 50 | codrington
# Processing Record 51 of set 51 | georgetown
# Processing Record 52 of set 52 | smithers
# Processing Record 53 of set 53 | trinidad
# Processing Record 54 of set 54 | barrow
# Processing Record 55 of set 55 | thompson
# Processing Record 56 of set 56 | bathsheba
# Processing Record 57 of set 57 | clyde river
# Processing Record 58 of set 58 | gat
# Processing Record 59 of set 59 | kapaa
# Processing Record 60 of set 60 | jonkoping
# Processing Record 61 of set 61 | cape town
# Processing Record 62 of set 62 | tuatapere
# Processing Record 63 of set 63 | nanortalik
# Processing Record 64 of set 64 | hobyo
# Processing Record 65 of set 65 | fjerritslev
# Processing Record 66 of set 66 | esperance
# Processing Record 67 of set 67 | ponta do sol
# Processing Record 68 of set 68 | la palma
# Processing Record 69 of set 69 | cherskiy
# Processing Record 70 of set 70 | hobart
# Processing Record 71 of set 71 | jinchang
# Processing Record 72 of set 72 | kavaratti
# Processing Record 73 of set 73 | mahon
# Processing Record 74 of set 74 | filimonovo
# Processing Record 75 of set 75 | vaini
# Processing Record 76 of set 76 | longyearbyen
# Processing Record 77 of set 77 | vaitupu
# City, vaitupu not found. Skipping...
# Processing Record 78 of set 78 | sofiysk
# City, sofiysk not found. Skipping...
# Processing Record 79 of set 79 | qaanaaq
# Processing Record 80 of set 80 | srednekolymsk
# Processing Record 81 of set 81 | jamestown
# Processing Record 82 of set 82 | saint-philippe
# Processing Record 83 of set 83 | persianovskiy
# Processing Record 84 of set 84 | mahadday weyne
# City, mahadday weyne not found. Skipping...
# Processing Record 85 of set 85 | baisha
# Processing Record 86 of set 86 | minden
# Processing Record 87 of set 87 | lorengau
# Processing Record 88 of set 88 | hithadhoo
# Processing Record 89 of set 89 | castro
# Processing Record 90 of set 90 | rikitea
# Processing Record 91 of set 91 | comodoro rivadavia
# Processing Record 92 of set 92 | tabou
# Processing Record 93 of set 93 | teguldet
# Processing Record 94 of set 94 | axim
# Processing Record 95 of set 95 | stepnyak
# Processing Record 96 of set 96 | uyutne
# Processing Record 97 of set 97 | sentyabrskiy
# City, sentyabrskiy not found. Skipping...
# Processing Record 98 of set 98 | methoni
# Processing Record 99 of set 99 | cabo san lucas
# Processing Record 100 of set 100 | nadlac
# Processing Record 101 of set 101 | kutum
# Processing Record 102 of set 102 | saldanha
# Processing Record 103 of set 103 | santa maria
# Processing Record 104 of set 104 | sept-iles
# Processing Record 105 of set 105 | taybad
# Processing Record 106 of set 106 | pangoa
# Processing Record 107 of set 107 | lamu
# Processing Record 108 of set 108 | buala
# Processing Record 109 of set 109 | kenai
# Processing Record 110 of set 110 | la asuncion
# Processing Record 111 of set 111 | labutta
# City, labutta not found. Skipping...
# Processing Record 112 of set 112 | attawapiskat
# City, attawapiskat not found. Skipping...
# Processing Record 113 of set 113 | port elizabeth
# Processing Record 114 of set 114 | karratha
# Processing Record 115 of set 115 | camacari
# Processing Record 116 of set 116 | dwarka
# Processing Record 117 of set 117 | pisco
# Processing Record 118 of set 118 | warqla
# City, warqla not found. Skipping...
# Processing Record 119 of set 119 | nizhneyansk
# City, nizhneyansk not found. Skipping...
# Processing Record 120 of set 120 | marsh harbour
# Processing Record 121 of set 121 | bosaso
# Processing Record 122 of set 122 | nikolskoye
# Processing Record 123 of set 123 | avarua
# Processing Record 124 of set 124 | kamenskoye
# City, kamenskoye not found. Skipping...
# Processing Record 125 of set 125 | la plata
# Processing Record 126 of set 126 | bredasdorp
# Processing Record 127 of set 127 | bambous virieux
# Processing Record 128 of set 128 | sandane
# Processing Record 129 of set 129 | ostrovnoy
# Processing Record 130 of set 130 | guerrero negro
# Processing Record 131 of set 131 | grand river south east
# City, grand river south east not found. Skipping...
# Processing Record 132 of set 132 | torbay
# Processing Record 133 of set 133 | scarborough
# Processing Record 134 of set 134 | irinjalakuda
# Processing Record 135 of set 135 | esqueda
# Processing Record 136 of set 136 | dikson
# Processing Record 137 of set 137 | yining
# Processing Record 138 of set 138 | cockburn town
# Processing Record 139 of set 139 | norman wells
# Processing Record 140 of set 140 | florida
# Processing Record 141 of set 141 | tambo
# Processing Record 142 of set 142 | mahebourg
# Processing Record 143 of set 143 | sur
# Processing Record 144 of set 144 | palauig
# Processing Record 145 of set 145 | bandrele
# Processing Record 146 of set 146 | taltal
# Processing Record 147 of set 147 | gladstone
# Processing Record 148 of set 148 | illoqqortoormiut
# City, illoqqortoormiut not found. Skipping...
# Processing Record 149 of set 149 | morro bay
# Processing Record 150 of set 150 | palabuhanratu
# City, palabuhanratu not found. Skipping...
# Processing Record 151 of set 151 | mar del plata
# Processing Record 152 of set 152 | opunake
# Processing Record 153 of set 153 | kamenka
# Processing Record 154 of set 154 | baturaja
# Processing Record 155 of set 155 | svetlyy
# Processing Record 156 of set 156 | atuona
# Processing Record 157 of set 157 | vila franca do campo
# Processing Record 158 of set 158 | kodiak
# Processing Record 159 of set 159 | kirensk
# Processing Record 160 of set 160 | carnarvon
# Processing Record 161 of set 161 | porto novo
# Processing Record 162 of set 162 | camapua
# Processing Record 163 of set 163 | arraial do cabo
# Processing Record 164 of set 164 | nasirabad
# Processing Record 165 of set 165 | kaitangata
# Processing Record 166 of set 166 | cidreira
# Processing Record 167 of set 167 | salalah
# Processing Record 168 of set 168 | belushya guba
# City, belushya guba not found. Skipping...
# Processing Record 169 of set 169 | bengkulu
# Processing Record 170 of set 170 | jega
# Processing Record 171 of set 171 | tessalit
# Processing Record 172 of set 172 | jabiru
# City, jabiru not found. Skipping...
# Processing Record 173 of set 173 | lebu
# Processing Record 174 of set 174 | erseke
# Processing Record 175 of set 175 | acopiara
# Processing Record 176 of set 176 | vardo
# Processing Record 177 of set 177 | waharoa
# Processing Record 178 of set 178 | kudahuvadhoo
# Processing Record 179 of set 179 | watrous
# Processing Record 180 of set 180 | hihifo
# City, hihifo not found. Skipping...
# Processing Record 181 of set 181 | sokoni
# Processing Record 182 of set 182 | waingapu
# Processing Record 183 of set 183 | korla
# Processing Record 184 of set 184 | darnah
# Processing Record 185 of set 185 | a coruna
# Processing Record 186 of set 186 | opuwo
# Processing Record 187 of set 187 | dingle
# Processing Record 188 of set 188 | tomigusuku
# Processing Record 189 of set 189 | marawi
# City, marawi not found. Skipping...
# Processing Record 190 of set 190 | aksarka
# Processing Record 191 of set 191 | tharad
# Processing Record 192 of set 192 | praia da vitoria
# Processing Record 193 of set 193 | muana
# Processing Record 194 of set 194 | santarem
# Processing Record 195 of set 195 | baruun-urt
# Processing Record 196 of set 196 | chekhov
# Processing Record 197 of set 197 | kismayo
# Processing Record 198 of set 198 | nizwa
# Processing Record 199 of set 199 | airai
# Processing Record 200 of set 200 | vestmannaeyjar
# Processing Record 201 of set 201 | borujan
# City, borujan not found. Skipping...
# Processing Record 202 of set 202 | wahran
# City, wahran not found. Skipping...
# Processing Record 203 of set 203 | sao filipe
# Processing Record 204 of set 204 | ippy
# Processing Record 205 of set 205 | burnie
# Processing Record 206 of set 206 | kresttsy
# Processing Record 207 of set 207 | kirakira
# Processing Record 208 of set 208 | iqaluit
# Processing Record 209 of set 209 | nyurba
# Processing Record 210 of set 210 | aklavik
# Processing Record 211 of set 211 | barrancas
# Processing Record 212 of set 212 | yulara
# Processing Record 213 of set 213 | maroantsetra
# Processing Record 214 of set 214 | hay river
# Processing Record 215 of set 215 | rawson
# Processing Record 216 of set 216 | moose factory
# Processing Record 217 of set 217 | chapais
# Processing Record 218 of set 218 | la ronge
# Processing Record 219 of set 219 | villa rica
# Processing Record 220 of set 220 | doha
# Processing Record 221 of set 221 | namibe
# Processing Record 222 of set 222 | sheridan
# Processing Record 223 of set 223 | marrakesh
# Processing Record 224 of set 224 | xingcheng
# Processing Record 225 of set 225 | toulepleu
# City, toulepleu not found. Skipping...
# Processing Record 226 of set 226 | chuy
# Processing Record 227 of set 227 | poladpur
# Processing Record 228 of set 228 | leshukonskoye
# Processing Record 229 of set 229 | aasiaat
# Processing Record 230 of set 230 | yellowknife
# Processing Record 231 of set 231 | egvekinot
# Processing Record 232 of set 232 | hawalli
# Processing Record 233 of set 233 | malartic
# Processing Record 234 of set 234 | camopi
# Processing Record 235 of set 235 | san patricio
# Processing Record 236 of set 236 | sorland
# Processing Record 237 of set 237 | tiksi
# Processing Record 238 of set 238 | san lawrenz
# Processing Record 239 of set 239 | mayahi
# Processing Record 240 of set 240 | terrace
# Processing Record 241 of set 241 | ileza
# Processing Record 242 of set 242 | yar-sale
# Processing Record 243 of set 243 | kholmogory
# Processing Record 244 of set 244 | sauce
# Processing Record 245 of set 245 | tricase
# Processing Record 246 of set 246 | ballina
# Processing Record 247 of set 247 | inhambane
# Processing Record 248 of set 248 | giyani
# Processing Record 249 of set 249 | raudeberg
# Processing Record 250 of set 250 | kaka
# Processing Record 251 of set 251 | kollam
# Processing Record 252 of set 252 | fortuna
# Processing Record 253 of set 253 | katangli
# Processing Record 254 of set 254 | port hardy
# Processing Record 255 of set 255 | eyl
# Processing Record 256 of set 256 | viligili
# City, viligili not found. Skipping...
# Processing Record 257 of set 257 | kidal
# Processing Record 258 of set 258 | hasaki
# Processing Record 259 of set 259 | severo-kurilsk
# Processing Record 260 of set 260 | amderma
# City, amderma not found. Skipping...
# Processing Record 261 of set 261 | khatanga
# Processing Record 262 of set 262 | tyrma
# Processing Record 263 of set 263 | peleduy
# Processing Record 264 of set 264 | zaozerne
# Processing Record 265 of set 265 | vilhena
# Processing Record 266 of set 266 | stokmarknes
# Processing Record 267 of set 267 | avera
# Processing Record 268 of set 268 | cap malheureux
# Processing Record 269 of set 269 | mangalia
# Processing Record 270 of set 270 | amberieu-en-bugey
# Processing Record 271 of set 271 | namikupa
# Processing Record 272 of set 272 | digras
# Processing Record 273 of set 273 | padang
# Processing Record 274 of set 274 | laguna
# Processing Record 275 of set 275 | buariki
# City, buariki not found. Skipping...
# Processing Record 276 of set 276 | dzhusaly
# City, dzhusaly not found. Skipping...
# Processing Record 277 of set 277 | shingu
# Processing Record 278 of set 278 | koungheul
# Processing Record 279 of set 279 | talnakh
# Processing Record 280 of set 280 | atagay
# Processing Record 281 of set 281 | isangel
# Processing Record 282 of set 282 | abu dhabi
# Processing Record 283 of set 283 | basoko
# Processing Record 284 of set 284 | marsa matruh
# Processing Record 285 of set 285 | sola
# Processing Record 286 of set 286 | rio grande
# Processing Record 287 of set 287 | thinadhoo
# Processing Record 288 of set 288 | yerbogachen
# Processing Record 289 of set 289 | kosum phisai
# Processing Record 290 of set 290 | harer
# Processing Record 291 of set 291 | alakurtti
# Processing Record 292 of set 292 | sovetskaya gavan
# Processing Record 293 of set 293 | caravelas
# Processing Record 294 of set 294 | tasiilaq
# Processing Record 295 of set 295 | faanui
# Processing Record 296 of set 296 | akdagmadeni
# Processing Record 297 of set 297 | luanda
# Processing Record 298 of set 298 | nouakchott
# Processing Record 299 of set 299 | luderitz
# Processing Record 300 of set 300 | mrirt
# City, mrirt not found. Skipping...
# Processing Record 301 of set 301 | trogir
# Processing Record 302 of set 302 | saleaula
# City, saleaula not found. Skipping...
# Processing Record 303 of set 303 | kerteh
# City, kerteh not found. Skipping...
# Processing Record 304 of set 304 | merauke
# Processing Record 305 of set 305 | nome
# Processing Record 306 of set 306 | pokrovskoye
# Processing Record 307 of set 307 | piotrkow trybunalski
# Processing Record 308 of set 308 | ketchikan
# Processing Record 309 of set 309 | khair
# Processing Record 310 of set 310 | kodinar
# Processing Record 311 of set 311 | crab hill
# City, crab hill not found. Skipping...
# Processing Record 312 of set 312 | vitim
# Processing Record 313 of set 313 | omsukchan
# Processing Record 314 of set 314 | yeppoon
# Processing Record 315 of set 315 | epinal
# Processing Record 316 of set 316 | jalu
# Processing Record 317 of set 317 | lompoc
# Processing Record 318 of set 318 | alice springs
# Processing Record 319 of set 319 | terre-de-bas
# Processing Record 320 of set 320 | valdepenas
# Processing Record 321 of set 321 | las vegas
# Processing Record 322 of set 322 | nakamura
# Processing Record 323 of set 323 | tarakan
# Processing Record 324 of set 324 | banjar
# Processing Record 325 of set 325 | zhigansk
# Processing Record 326 of set 326 | los llanos de aridane
# Processing Record 327 of set 327 | san buenaventura
# Processing Record 328 of set 328 | valdivia
# Processing Record 329 of set 329 | faya
# Processing Record 330 of set 330 | tura
# Processing Record 331 of set 331 | champerico
# Processing Record 332 of set 332 | upata
# Processing Record 333 of set 333 | victoria
# Processing Record 334 of set 334 | digha
# Processing Record 335 of set 335 | batagay-alyta
# Processing Record 336 of set 336 | kruisfontein
# Processing Record 337 of set 337 | flinders
# Processing Record 338 of set 338 | mehamn
# Processing Record 339 of set 339 | awjilah
# Processing Record 340 of set 340 | kleck
# City, kleck not found. Skipping...
# Processing Record 341 of set 341 | atikokan
# Processing Record 342 of set 342 | boden
# Processing Record 343 of set 343 | vila
# Processing Record 344 of set 344 | kamaishi
# Processing Record 345 of set 345 | santa cruz del norte
# Processing Record 346 of set 346 | amahai
# Processing Record 347 of set 347 | amapa
# Processing Record 348 of set 348 | ambulu
# Processing Record 349 of set 349 | lolua
# City, lolua not found. Skipping...
# Processing Record 350 of set 350 | lashio
# Processing Record 351 of set 351 | coahuayana
# Processing Record 352 of set 352 | salinas
# Processing Record 353 of set 353 | hailar
# Processing Record 354 of set 354 | voh
# Processing Record 355 of set 355 | lagoa
# Processing Record 356 of set 356 | olafsvik
# Processing Record 357 of set 357 | jeremie
# Processing Record 358 of set 358 | aykhal
# Processing Record 359 of set 359 | deep river
# Processing Record 360 of set 360 | brejo santo
# Processing Record 361 of set 361 | muros
# Processing Record 362 of set 362 | neiafu
# Processing Record 363 of set 363 | ahipara
# Processing Record 364 of set 364 | garowe
# Processing Record 365 of set 365 | camambugan
# Processing Record 366 of set 366 | ilulissat
# Processing Record 367 of set 367 | ordynskoye
# Processing Record 368 of set 368 | malpe
# Processing Record 369 of set 369 | imeni poliny osipenko
# Processing Record 370 of set 370 | yokadouma
# Processing Record 371 of set 371 | yumen
# Processing Record 372 of set 372 | jiaojiang
# Processing Record 373 of set 373 | kapiri mposhi
# Processing Record 374 of set 374 | katherine
# Processing Record 375 of set 375 | havre
# Processing Record 376 of set 376 | kathu
# Processing Record 377 of set 377 | guskhara
# Processing Record 378 of set 378 | tsihombe
# City, tsihombe not found. Skipping...
# Processing Record 379 of set 379 | bocaranga
# City, bocaranga not found. Skipping...
# Processing Record 380 of set 380 | san rafael
# Processing Record 381 of set 381 | atar
# Processing Record 382 of set 382 | homer
# Processing Record 383 of set 383 | anadyr
# Processing Record 384 of set 384 | kurilsk
# Processing Record 385 of set 385 | emerald
# Processing Record 386 of set 386 | tuggurt
# City, tuggurt not found. Skipping...
# Processing Record 387 of set 387 | ancud
# Processing Record 388 of set 388 | saint simons
# Processing Record 389 of set 389 | stephenville
# Processing Record 390 of set 390 | kahului
# Processing Record 391 of set 391 | ouadda
# Processing Record 392 of set 392 | port hedland
# Processing Record 393 of set 393 | mys shmidta
# City, mys shmidta not found. Skipping...
# Processing Record 394 of set 394 | wladyslawowo
# Processing Record 395 of set 395 | westport
# Processing Record 396 of set 396 | shimoda
# Processing Record 397 of set 397 | iquira
# Processing Record 398 of set 398 | brae
# Processing Record 399 of set 399 | cabedelo
# Processing Record 400 of set 400 | sawakin
# Processing Record 401 of set 401 | hashtrud
# Processing Record 402 of set 402 | barra patuca
# Processing Record 403 of set 403 | kongoussi
# Processing Record 404 of set 404 | broome
# Processing Record 405 of set 405 | lieksa
# Processing Record 406 of set 406 | curuca
# Processing Record 407 of set 407 | doctor arroyo
# Processing Record 408 of set 408 | koplik
# Processing Record 409 of set 409 | wajir
# Processing Record 410 of set 410 | dinguiraye
# Processing Record 411 of set 411 | jumla
# Processing Record 412 of set 412 | olga
# Processing Record 413 of set 413 | dandong
# Processing Record 414 of set 414 | itarema
# Processing Record 415 of set 415 | yatou
# Processing Record 416 of set 416 | darab
# Processing Record 417 of set 417 | puerto madryn
# Processing Record 418 of set 418 | bunbury
# Processing Record 419 of set 419 | krasnoselkup
# Processing Record 420 of set 420 | sioux lookout
# Processing Record 421 of set 421 | juba
# Processing Record 422 of set 422 | port blair
# Processing Record 423 of set 423 | nouadhibou
# Processing Record 424 of set 424 | kedarnath
# City, kedarnath not found. Skipping...
# Processing Record 425 of set 425 | puerto cabello
# Processing Record 426 of set 426 | kangaba
# Processing Record 427 of set 427 | geraldton
# Processing Record 428 of set 428 | necochea
# Processing Record 429 of set 429 | arlit
# Processing Record 430 of set 430 | san vicente
# Processing Record 431 of set 431 | stornoway
# Processing Record 432 of set 432 | lesozavodsk
# Processing Record 433 of set 433 | mbandaka
# Processing Record 434 of set 434 | port-gentil
# Processing Record 435 of set 435 | baracoa
# Processing Record 436 of set 436 | tautira
# Processing Record 437 of set 437 | alto araguaia
# Processing Record 438 of set 438 | lamar
# Processing Record 439 of set 439 | price
# Processing Record 440 of set 440 | ulladulla
# Processing Record 441 of set 441 | zyryanka
# Processing Record 442 of set 442 | gao
# Processing Record 443 of set 443 | albury
# Processing Record 444 of set 444 | rio gallegos
# Processing Record 445 of set 445 | shumskiy
# Processing Record 446 of set 446 | tabas
# Processing Record 447 of set 447 | isiro
# Processing Record 448 of set 448 | chagda
# City, chagda not found. Skipping...
# Processing Record 449 of set 449 | karkaralinsk
# City, karkaralinsk not found. Skipping...
# Processing Record 450 of set 450 | mocuba
# Processing Record 451 of set 451 | jutai
# Processing Record 452 of set 452 | sweetwater
# Processing Record 453 of set 453 | belmonte
# Processing Record 454 of set 454 | noyabrsk
# Processing Record 455 of set 455 | beloha
# Processing Record 456 of set 456 | farmington
# Processing Record 457 of set 457 | asau
# Processing Record 458 of set 458 | bereda
# Processing Record 459 of set 459 | louisbourg
# City, louisbourg not found. Skipping...
# Processing Record 460 of set 460 | huilong
# Processing Record 461 of set 461 | sogdiondon
# City, sogdiondon not found. Skipping...
# Processing Record 462 of set 462 | jackson
# Processing Record 463 of set 463 | mangrol
# Processing Record 464 of set 464 | shkotovo-26
# City, shkotovo-26 not found. Skipping...
# Processing Record 465 of set 465 | vila velha
# Processing Record 466 of set 466 | hambantota
# Processing Record 467 of set 467 | grootfontein
# Processing Record 468 of set 468 | whitehorse
# Processing Record 469 of set 469 | yermakovskoye
# Processing Record 470 of set 470 | chumikan
# Processing Record 471 of set 471 | verkhoyansk
# Processing Record 472 of set 472 | skalistyy
# City, skalistyy not found. Skipping...
# Processing Record 473 of set 473 | takoradi
# Processing Record 474 of set 474 | morondava
# Processing Record 475 of set 475 | sisimiut
# Processing Record 476 of set 476 | kasempa
# Processing Record 477 of set 477 | sao gabriel da cachoeira
# Processing Record 478 of set 478 | grand gaube
# Processing Record 479 of set 479 | betare oya
# Processing Record 480 of set 480 | colombier
# Processing Record 481 of set 481 | mount isa
# Processing Record 482 of set 482 | nadym
# Processing Record 483 of set 483 | menomonie
# Processing Record 484 of set 484 | qena
# Processing Record 485 of set 485 | tucuman
# Processing Record 486 of set 486 | jining
# Processing Record 487 of set 487 | san alberto
# Processing Record 488 of set 488 | betsiamites
# Processing Record 489 of set 489 | posyet
# Processing Record 490 of set 490 | praia
# Processing Record 491 of set 491 | cayenne
# Processing Record 492 of set 492 | alyangula
# Processing Record 493 of set 493 | bukama
# Processing Record 494 of set 494 | plettenberg bay
# Processing Record 495 of set 495 | loikaw
# Processing Record 496 of set 496 | sesheke
# Processing Record 497 of set 497 | hualmay
# Processing Record 498 of set 498 | pevek
# Processing Record 499 of set 499 | santa marta
# Processing Record 500 of set 500 | labuhan
# Processing Record 501 of set 501 | vanimo
# Processing Record 502 of set 502 | berlevag
# Processing Record 503 of set 503 | uaua
# Processing Record 504 of set 504 | kangaatsiaq
# Processing Record 505 of set 505 | paramonga
# Processing Record 506 of set 506 | carutapera
# Processing Record 507 of set 507 | navahrudak
# Processing Record 508 of set 508 | liwale
# Processing Record 509 of set 509 | saint-pierre
# Processing Record 510 of set 510 | maple creek
# Processing Record 511 of set 511 | bam
# Processing Record 512 of set 512 | nantucket
# Processing Record 513 of set 513 | sale
# Processing Record 514 of set 514 | casablanca
# Processing Record 515 of set 515 | agadez
# Processing Record 516 of set 516 | carlisle
# Processing Record 517 of set 517 | reconquista
# Processing Record 518 of set 518 | umm kaddadah
# Processing Record 519 of set 519 | bac lieu
# Processing Record 520 of set 520 | khormuj
# City, khormuj not found. Skipping...
# Processing Record 521 of set 521 | kloulklubed
# Processing Record 522 of set 522 | carballo
# Processing Record 523 of set 523 | olinda
# Processing Record 524 of set 524 | kavieng
# Processing Record 525 of set 525 | genhe
# Processing Record 526 of set 526 | rondon
# Processing Record 527 of set 527 | mildura
# Processing Record 528 of set 528 | ewa beach
# Processing Record 529 of set 529 | bay roberts
# Processing Record 530 of set 530 | pitimbu
# Processing Record 531 of set 531 | sarahan
# Processing Record 532 of set 532 | clarence town
# Processing Record 533 of set 533 | labateca
# Processing Record 534 of set 534 | jaciara
# Processing Record 535 of set 535 | pangnirtung
# Processing Record 536 of set 536 | juifang
# City, juifang not found. Skipping...
# Processing Record 537 of set 537 | kadirli
# Processing Record 538 of set 538 | vao
# Processing Record 539 of set 539 | port hawkesbury
# Processing Record 540 of set 540 | parbatipur
# Processing Record 541 of set 541 | brasilia de minas
# Processing Record 542 of set 542 | sarangani
# Processing Record 543 of set 543 | tambul
# City, tambul not found. Skipping...
# Processing Record 544 of set 544 | mount gambier
# Processing Record 545 of set 545 | sorkjosen
# Processing Record 546 of set 546 | tumannyy
# City, tumannyy not found. Skipping...
# Processing Record 547 of set 547 | san quintin
# Processing Record 548 of set 548 | manavalakurichi
# Processing Record 549 of set 549 | hirara
# Processing Record 550 of set 550 | navabad
# City, navabad not found. Skipping...
# Processing Record 551 of set 551 | penzance
# Processing Record 552 of set 552 | zhitikara
# City, zhitikara not found. Skipping...
# Processing Record 553 of set 553 | nola
# Processing Record 554 of set 554 | iroquois falls
# Processing Record 555 of set 555 | bowen
# Processing Record 556 of set 556 | capinopolis
# Processing Record 557 of set 557 | atbasar
# Processing Record 558 of set 558 | gubakha
# Processing Record 559 of set 559 | san lorenzo
# Processing Record 560 of set 560 | vestnes
# Processing Record 561 of set 561 | provideniya
# Processing Record 562 of set 562 | bonthe
# Processing Record 563 of set 563 | kimbe
# Processing Record 564 of set 564 | halifax
# Processing Record 565 of set 565 | chimay
# Processing Record 566 of set 566 | bida
# Processing Record 567 of set 567 | bairiki
# Processing Record 568 of set 568 | lenger
# Processing Record 569 of set 569 | kaeo
# Processing Record 570 of set 570 | lima
# Processing Record 571 of set 571 | baykalsk
# Processing Record 572 of set 572 | port lincoln
# Processing Record 573 of set 573 | senmonorom
# City, senmonorom not found. Skipping...
# Processing Record 574 of set 574 | pailon
# Processing Record 575 of set 575 | siocon
# Processing Record 576 of set 576 | brindisi
# Processing Record 577 of set 577 | magugu
# Processing Record 578 of set 578 | sinnamary
# Processing Record 579 of set 579 | college
# Processing Record 580 of set 580 | blagoyevo
# Processing Record 581 of set 581 | touros
# Processing Record 582 of set 582 | tomatlan
# Processing Record 583 of set 583 | barcelona
# Processing Record 584 of set 584 | puerto baquerizo moreno
# Processing Record 585 of set 585 | ozieri
# Processing Record 586 of set 586 | obo
# Processing Record 587 of set 587 | kalianget
# Processing Record 588 of set 588 | anyama
# Processing Record 589 of set 589 | woodward
# Processing Record 590 of set 590 | ardistan
# City, ardistan not found. Skipping...
# Processing Record 591 of set 591 | manono
# Processing Record 592 of set 592 | gizo
# Processing Record 593 of set 593 | halalo
# City, halalo not found. Skipping...
# Processing Record 594 of set 594 | loiza
# Processing Record 595 of set 595 | bell ville
# Processing Record 596 of set 596 | paamiut
# Processing Record 597 of set 597 | minas
# Processing Record 598 of set 598 | hamilton
# Processing Record 599 of set 599 | luocheng
# Processing Record 600 of set 600 | ust-kuyga
# Processing Record 601 of set 601 | minggang
# Processing Record 602 of set 602 | uddevalla
# Processing Record 603 of set 603 | madanapalle
# Processing Record 604 of set 604 | phuntsholing
# Processing Record 605 of set 605 | starychi
# Processing Record 606 of set 606 | souillac
# Processing Record 607 of set 607 | oswego
# Processing Record 608 of set 608 | kanigiri
# Processing Record 609 of set 609 | carlagan
# Processing Record 610 of set 610 | qaqortoq
# Processing Record 611 of set 611 | villaviciosa
# Processing Record 612 of set 612 | fowa
# Processing Record 613 of set 613 | ocampo
# Processing Record 614 of set 614 | alta floresta
# Processing Record 615 of set 615 | sisophon
# Processing Record 616 of set 616 | banda aceh
# Processing Record 617 of set 617 | venice
# Processing Record 618 of set 618 | margate
# Processing Record 619 of set 619 | puerto colombia
# Processing Record 620 of set 620 | san policarpo
# Processing Record 621 of set 621 | san jose
# --------------------------------------------
# Data Retrieval Complete
# --------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create Data Frame
weather_dict = {"Country": country,
              "Lat": lat,
              "Lon": lon,
              "Temp": temp,
              "Humidity": humid,
              "Cloudiness": cloud,
              "Wind Speed": wind,
              "City": cities_found,
              "Date": date
              }

weather_df = pd.DataFrame(weather_dict)

# Export to CSV
weather_df.head()
# Out:
#   Country    Lat     Lon   Temp  Humidity  Cloudiness  Wind Speed  \
# 0      CA  69.45 -133.04  66.20        48          75        3.36
# 1      EC  -0.74  -90.35  68.00        93          66        5.99
# 2      RU  56.67   96.06  60.87        65         100        3.51
# 3      SY  35.30   37.18  71.37        62           0       13.00
# 4      KZ  43.60   73.76  75.99        61          46        6.98
#
#            City        Date
# 0   Tuktoyaktuk  1595637988
# 1  Puerto Ayora  1595637988
# 2          Aban  1595638358
# 3    Abu Samrah  1595638359
# 4           Chu  1595638360

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_over100 = weather_df.loc[weather_df["Humidity"] >100]
humidity_over100.head(25)
# Out:
# Empty DataFrame
# Columns: [Country, Lat, Lon, Temp, Humidity, Cloudiness, Wind Speed, City, Date]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
clean_city_data = weather_df.drop(weather_df.loc[weather_df['Humidity'] > 100].index, inplace=False)
clean_city_data.head()
# Out:
#   Country    Lat     Lon   Temp  Humidity  Cloudiness  Wind Speed  \
# 0      CA  69.45 -133.04  66.20        48          75        3.36
# 1      EC  -0.74  -90.35  68.00        93          66        5.99
# 2      RU  56.67   96.06  60.87        65         100        3.51
# 3      SY  35.30   37.18  71.37        62           0       13.00
# 4      KZ  43.60   73.76  75.99        61          46        6.98
#
#            City        Date
# 0   Tuktoyaktuk  1595637988
# 1  Puerto Ayora  1595637988
# 2          Aban  1595638358
# 3    Abu Samrah  1595638359
# 4           Chu  1595638360

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Scatter Plot Latitude vs Temperature
plt.scatter(weather_df['Lat'], weather_df['Temp'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("Latitude vs Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Scatter Plot Latitude vs Humidity
plt.scatter(weather_df['Lat'], weather_df['Humidity'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Scatter Plot Latitude vs Cloudiness
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Scatter Plot Latitude vs Temperature
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern & Southern Hemisphere DataFrames
northern_df = clean_city_data.loc[clean_city_data['Lat'] >= 0]
southern_df = clean_city_data.loc[clean_city_data['Lat'] < 0]
northern_df.head()
southern_df.head()
# Out:
#    Country    Lat     Lon   Temp  Humidity  Cloudiness  Wind Speed  \
# 1       EC  -0.74  -90.35  68.00        93          66        5.99
# 8       AU -15.77  128.73  77.00        18           0        6.93
# 9       ZA -33.02   27.91  64.58        26           0        4.85
# 11      AR -33.75  -61.97  43.92        57           0        8.16
# 12      AU -42.78  147.06  46.35        81         100        2.28
#
#              City        Date
# 1    Puerto Ayora  1595637988
# 8       Kununurra  1595638023
# 9     East London  1595637987
# 11  Venado Tuerto  1595638365
# 12    New Norfolk  1595637986

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Northern Hemisphere-Max Temp vs Latitude Linear Regression
x_values = southern_df['Temp']
y_values = southern_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.scatter(northern_df['Temp'], northern_df['Lat'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
print(f"R squared: {rvalue**2}")
plt.title("Northern Hemisphere-Max Temperature vs Latitude Linear Regression")
plt.xlabel("Temperature")
plt.ylabel("Latitude")
plt.show()
# Out:
# R squared: 0.5910533019173994

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Southern Hemisphere-Max Temp vs Latitude Linear Regression
x_values = southern_df['Temp']
y_values = southern_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.scatter(southern_df['Temp'], southern_df['Lat'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
print(f"R squared: {rvalue**2}")
plt.title("Southern Hemisphere-Max Temperature vs Latitude Linear Regression")
plt.xlabel("Temperature")
plt.ylabel("Latitude")
plt.show()
# Out:
# R squared: 0.5910533019173994

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere-Humidity(%) vs Latitude Linear Regression
x_values = northern_df['Humidity']
y_values = northern_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.scatter(northern_df['Humidity'], northern_df['Lat'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
print(f"R squared: {rvalue**2}")
plt.title("Northern Hemisphere-Humidity(%) vs Latitude Linear Regression")
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.show()
# Out:
# R squared: 0.005807551151741692

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere-Humidity(%) vs Latitude Linear Regression
x_values = southern_df['Humidity']
y_values = southern_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.scatter(southern_df['Temp'], southern_df['Lat'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
print(f"R squared: {rvalue**2}")
plt.title("Southern Hemisphere-Humidity(%) vs Latitude Linear Regression")
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.show()
# Out:
# R squared: 0.0007832906642727873

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere-Cloudiness(%) vs Latitude Linear Regression
x_values = northern_df['Cloudiness']
y_values = northern_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.scatter(northern_df['Cloudiness'], northern_df['Lat'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
print(f"R squared: {rvalue**2}")
plt.title("Northern Hemisphere-Cloudiness(%) vs Latitude Linear Regression")
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.show()
# Out:
# R squared: 0.003289354828385392

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere-Cloudiness(%) vs Latitude Linear Regression
x_values = southern_df['Cloudiness']
y_values = southern_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.scatter(southern_df['Cloudiness'], southern_df['Lat'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
print(f"R squared: {rvalue**2}")
plt.title("Southern Hemisphere-Cloudiness(%) vs Latitude Linear Regression")
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.show()
# Out:
# R squared: 0.0019906095381761373

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere-Wind Speed (mph) vs Latitude Linear Regression
x_values = northern_df['Wind Speed']
y_values = northern_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.scatter(northern_df['Wind Speed'], northern_df['Lat'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
print(f"R squared: {rvalue**2}")
plt.title("Northern Hemisphere-Wind Speed vs Latitude Linear Regression")
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.show()
# Out:
# R squared: 1.5122423158255835e-06

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere-Wind Speed (mph) vs Latitude Linear Regression
x_values = southern_df['Wind Speed']
y_values = southern_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.scatter(southern_df['Wind Speed'], southern_df['Lat'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
print(f"R squared: {rvalue**2}")
plt.title("Southern Hemisphere-wind Speed (mph) vs Latitude Linear Regression")
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.show()
# Out:
# R squared: 0.010639314321863099
